# %%
#!/usr/bin/env python3
import os
import sys
import json
from pathlib import Path

def is_lerobot_dataset(dir_path: Path) -> bool:
    """检查是否为 LeRobot 数据集"""
    data_dir = dir_path / "data"
    meta_dir = dir_path / "meta"
    info_file = meta_dir / "info.json"
    
    if data_dir.is_dir() and meta_dir.is_dir() and info_file.is_file():
        try:
            with open(info_file, 'r', encoding='utf-8') as f:
                json.load(f)          # 验证 JSON 格式
            return True
        except:
            return False
    return False

def find_lerobot_datasets(root_path: Path, output_file: str = "lerobot_datasets.txt"):
    """递归查找所有 LeRobot 数据集"""
    found = []
    print(f"正在搜索: {root_path}\n")
    
    for dirpath, _, _ in os.walk(root_path):
        current = Path(dirpath)
        if is_lerobot_dataset(current):
            full_path = str(current.absolute())
            found.append(full_path)
            print(f"✅ 找到 LeRobot 数据集: {full_path}")
    
    if found:
        with open(output_file, 'w', encoding='utf-8') as f:
            for p in sorted(found):
                f.write(p + '\n')
        print(f"\n🎉 共找到 {len(found)} 个 LeRobot 数据集！")
        print(f"路径已保存至: {output_file}")
    else:
        print("\n未找到任何 LeRobot 数据集。")

if __name__ == "__main__":
    # if len(sys.argv) < 2:
    #     print("使用方法: python find_lerobot_datasets.py <搜索路径>")
    #     sys.exit(1)
    
    # root = Path(sys.argv[1]).expanduser().resolve()
    
    # if not root.is_dir():
    #     print(f"错误: {root} 不是有效文件夹")
    #     sys.exit(1)
    root = "/home/jovyan/vla-pretrain/egodex-lerobotv30"
    find_lerobot_datasets(root)
# Out:
# 正在搜索: /home/jovyan/vla-pretrain/egodex-lerobotv30
#
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/flip_pages
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/insert_remove_airpods
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/paint_clean_brush
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/stack_remove_jenga
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/load_dispense_ice
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/assemble_disassemble_furniture_bench_square_table
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/insert_remove_cups_from_rack
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/wash_put_away_dishes
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/clean_surface
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/pick_up_and_put_down_case_or_bag
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/insert_remove_tennis_ball
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/flip_coin
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/tie_untie_rubberband
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/point_and_click_remote
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/insert_remove_bagging
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/dry_hands
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/wash_fruit
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/rake_smooth_zen_garden
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/lock_unlock_key
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/zip_unzip_bag
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/assemble_jenga
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/build_unstack_lego
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/screw_unscrew_bottle_cap
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/slot_batteries
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/charge_uncharge_device
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/insert_remove_drawer
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/throw_collect_objects
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/braid_unbraid
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/assemble_disassemble_tiles
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/crumple_flatten_paper
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/assemble_disassemble_legos
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/zip_unzip_case
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/open_close_insert_remove_box
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/screw_unscrew_allen_fixture
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/fold_unfold_paper_origami
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/fry_egg
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/insert_remove_utensils
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/roll_ball
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/basic_pick_place
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/assemble_disassemble_furniture_bench_lamp
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/set_up_clean_up_chessboard
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/pick_place_food
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/basic_fold
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/assemble_disassemble_structures
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/deal_gather_cards
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/color
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/tie_and_untie_shoelace
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/put_away_set_up_board_game
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/setup_cleanup_table
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/throw_and_catch_ball
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/pour
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/clean_cups
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/put_toothpaste_on_toothbrush
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/play_mancala
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/gather_roll_dice
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/assemble_disassemble_furniture_bench_drawer
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/insert_remove_bookshelf
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/wipe_kitchen_surfaces
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/sweep_dustpan
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/vertical_pick_place
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/put_in_take_out_glasses
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/peel_place_sticker
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/make_sandwich
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/stack_unstack_cups
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/stack
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/arrange_topple_dominoes
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/play_piano
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/fry_bread
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/wrap_unwrap_food
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/fold_unfold_paper_basic
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/insert_remove_furniture_bench_round_table
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/use_rubiks_cube
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/assemble_disassemble_soft_legos
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/use_chopsticks
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/charge_uncharge_airpods
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/stack_unstack_bowls
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/write
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/open_close_insert_remove_case
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/stack_unstack_tupperware
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/fold_stack_unstack_unfold_cloths
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/sort_beads
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/play_reset_connect_four
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/wash_kitchen_dishes
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/knead_slime
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/push_pop_toy
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/fidget_magnetic_spinner_rings
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/declutter_desk
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/boil_serve_egg
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/clean_tableware
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/assemble_disassemble_furniture_bench_stool
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/insert_remove_furniture_bench_cabinet
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/insert_remove_plug_socket
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/type_keyboard
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/wipe_screen
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/add_remove_lid
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/sleeve_unsleeve_cards
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/stock_unstock_fridge
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/assemble_disassemble_furniture_bench_desk
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/open_close_insert_remove_tupperware
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/stack_unstack_plates
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/assemble_disassemble_furniture_bench_chair
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/wrap
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/clip_unclip_papers
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/thread_unthread_bead_necklace
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/insert_remove_usb
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/staple_paper
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/insert_dump_blocks
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/scoop_dump_ice
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/measure_objects
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/screw_unscrew_fingers_fixture
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/test/insert_remove_shirt_in_tube
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/vertical_pick_place-part5
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/flip_pages
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/insert_remove_airpods
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/paint_clean_brush
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/stack_remove_jenga
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/load_dispense_ice
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/assemble_disassemble_furniture_bench_square_table
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/play_piano-part1
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/insert_remove_cups_from_rack
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/wash_put_away_dishes
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/clean_surface
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/pick_up_and_put_down_case_or_bag
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/insert_remove_tennis_ball
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/flip_coin
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/tie_untie_rubberband
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/point_and_click_remote
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/insert_remove_bagging
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/dry_hands
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/wash_fruit
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/thread_unthread_bead_necklace-part2
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/vertical_pick_place-part1
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/thread_unthread_bead_necklace-part3
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/basic_pick_place-part3
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/rake_smooth_zen_garden
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/lock_unlock_key
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/zip_unzip_bag
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/assemble_jenga
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/build_unstack_lego
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/screw_unscrew_bottle_cap
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/slot_batteries
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/charge_uncharge_device
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/insert_remove_drawer
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/throw_collect_objects
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/braid_unbraid
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/basic_pick_place-part6
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/vertical_pick_place-part2
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/assemble_disassemble_tiles
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/basic_pick_place-part2
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/basic_fold-part1
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/crumple_flatten_paper
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/assemble_disassemble_legos
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/zip_unzip_case
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/basic_pick_place-part1
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/open_close_insert_remove_box
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/screw_unscrew_allen_fixture
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/fold_unfold_paper_origami
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/fry_egg
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/basic_pick_place-part5
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/insert_remove_utensils
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/roll_ball
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/assemble_disassemble_furniture_bench_lamp
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/set_up_clean_up_chessboard
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/pick_place_food
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/assemble_disassemble_structures
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/vertical_pick_place-part6
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/deal_gather_cards
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/color
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/tie_and_untie_shoelace
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/put_away_set_up_board_game
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/setup_cleanup_table
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/throw_and_catch_ball
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/pour
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/clean_cups
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/put_toothpaste_on_toothbrush
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/play_mancala
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/gather_roll_dice
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/assemble_disassemble_furniture_bench_drawer
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/insert_remove_bookshelf
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/wipe_kitchen_surfaces
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/sweep_dustpan
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/put_in_take_out_glasses
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/peel_place_sticker
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/vertical_pick_place-part4
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/make_sandwich
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/stack_unstack_cups
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/stack
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/basic_pick_place-part4
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/arrange_topple_dominoes
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/fry_bread
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/wrap_unwrap_food
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/basic_fold-part3
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/fold_unfold_paper_basic
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/insert_remove_furniture_bench_round_table
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/vertical_pick_place-part3
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/use_rubiks_cube
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/assemble_disassemble_soft_legos
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/use_chopsticks
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/charge_uncharge_airpods
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/stack_unstack_bowls
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/write
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/open_close_insert_remove_case
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/stack_unstack_tupperware
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/fold_stack_unstack_unfold_cloths
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/sort_beads
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/play_reset_connect_four
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/wash_kitchen_dishes
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/knead_slime
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/basic_fold-part6
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/push_pop_toy
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/fidget_magnetic_spinner_rings
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/declutter_desk
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/basic_fold-part2
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/play_piano-part2
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/boil_serve_egg
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/clean_tableware
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/assemble_disassemble_furniture_bench_stool
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/insert_remove_furniture_bench_cabinet
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/insert_remove_plug_socket
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/type_keyboard
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/wipe_screen
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/add_remove_lid
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/sleeve_unsleeve_cards
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/stock_unstock_fridge
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/assemble_disassemble_furniture_bench_desk
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/thread_unthread_bead_necklace-part1
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/open_close_insert_remove_tupperware
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/stack_unstack_plates
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/assemble_disassemble_furniture_bench_chair
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/wrap
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/clip_unclip_papers
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/basic_fold-part5
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/insert_remove_usb
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/staple_paper
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/insert_dump_blocks
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/scoop_dump_ice
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/measure_objects
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/screw_unscrew_fingers_fixture
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/basic_fold-part4
# ✅ 找到 LeRobot 数据集: /home/jovyan/vla-pretrain/egodex-lerobotv30/egodex-lerobotv30/train/insert_remove_shirt_in_tube
#
# 🎉 共找到 240 个 LeRobot 数据集！
# 路径已保存至: lerobot_datasets.txt
