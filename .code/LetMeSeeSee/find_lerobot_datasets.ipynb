# %%
#!/usr/bin/env python3
import os
import sys
import json
from pathlib import Path

def is_lerobot_dataset(dir_path: Path) -> bool:
    """检查是否为 LeRobot 数据集"""
    data_dir = dir_path / "data"
    meta_dir = dir_path / "meta"
    info_file = meta_dir / "info.json"
    
    if data_dir.is_dir() and meta_dir.is_dir() and info_file.is_file():
        try:
            with open(info_file, 'r', encoding='utf-8') as f:
                json.load(f)          # 验证 JSON 格式
            return True
        except:
            return False
    return False

def find_lerobot_datasets(root_path: Path, output_file: str = "lerobot_datasets.txt"):
    """递归查找所有 LeRobot 数据集"""
    found = []
    print(f"正在搜索: {root_path}\n")
    
    for dirpath, _, _ in os.walk(root_path):
        current = Path(dirpath)
        if is_lerobot_dataset(current):
            full_path = str(current.absolute())
            found.append(full_path)
            print(f"✅ 找到 LeRobot 数据集: {full_path}")
    
    if found:
        with open(output_file, 'w', encoding='utf-8') as f:
            for p in sorted(found):
                f.write(p + '\n')
        print(f"\n🎉 共找到 {len(found)} 个 LeRobot 数据集！")
        print(f"路径已保存至: {output_file}")
    else:
        print("\n未找到任何 LeRobot 数据集。")

if __name__ == "__main__":
    # if len(sys.argv) < 2:
    #     print("使用方法: python find_lerobot_datasets.py <搜索路径>")
    #     sys.exit(1)
    
    # root = Path(sys.argv[1]).expanduser().resolve()
    
    # if not root.is_dir():
    #     print(f"错误: {root} 不是有效文件夹")
    #     sys.exit(1)
    root = "/vla/workspace/data/robotwin2.0"
    find_lerobot_datasets(root,output_file=f"{root}/lerobot_datasets.txt")
# Out:
# 正在搜索: /vla/workspace/data/robotwin2.0
#
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/blocks_ranking_size/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/blocks_ranking_size/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/shake_bottle/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/shake_bottle/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/stack_blocks_three/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/stack_blocks_three/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_a2b_left/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_a2b_left/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/move_can_pot/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/move_can_pot/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_mouse_pad/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_mouse_pad/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_object_stand/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_object_stand/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/move_pillbottle_pad/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/move_pillbottle_pad/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/handover_block/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/handover_block/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/scan_object/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/scan_object/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_phone_stand/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_phone_stand/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/click_alarmclock/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/click_alarmclock/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/dump_bin_bigbin/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/dump_bin_bigbin/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_object_scale/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_object_scale/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/stamp_seal/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/stamp_seal/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/adjust_bottle/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/adjust_bottle/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/adjust_bottle/singe_clean_100
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/adjust_bottle/aloha-agilex_randomized_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_bread_basket/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_bread_basket/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/pick_diverse_bottles/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/pick_diverse_bottles/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/stack_bowls_three/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/stack_bowls_three/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/move_playingcard_away/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/move_playingcard_away/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/handover_mic/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/handover_mic/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/hanging_mug/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/hanging_mug/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/rotate_qrcode/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/rotate_qrcode/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_fan/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_fan/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/press_stapler/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/press_stapler/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/turn_switch/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/turn_switch/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/put_object_cabinet/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/put_object_cabinet/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/open_microwave/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/open_microwave/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_container_plate/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_container_plate/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_burger_fries/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_burger_fries/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/stack_bowls_two/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/stack_bowls_two/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_shoe/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_shoe/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_can_basket/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_can_basket/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/move_stapler_pad/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/move_stapler_pad/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_a2b_right/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_a2b_right/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/pick_dual_bottles/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/pick_dual_bottles/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/click_bell/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/click_bell/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_bread_skillet/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_bread_skillet/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/lift_pot/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/lift_pot/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/beat_block_hammer/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/beat_block_hammer/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/shake_bottle_horizontally/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/shake_bottle_horizontally/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/put_bottles_dustbin/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/put_bottles_dustbin/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_empty_cup/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_empty_cup/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/blocks_ranking_rgb/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/blocks_ranking_rgb/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_dual_shoes/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_dual_shoes/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/open_laptop/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/open_laptop/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_object_basket/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_object_basket/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/grab_roller/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/grab_roller/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_cans_plasticbox/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/place_cans_plasticbox/aloha-agilex_randomized_500
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/stack_blocks_two/aloha-agilex_clean_50
# ✅ 找到 LeRobot 数据集: /vla/workspace/data/robotwin2.0/stack_blocks_two/aloha-agilex_randomized_500
#
# 🎉 共找到 102 个 LeRobot 数据集！
# 路径已保存至: /vla/workspace/data/robotwin2.0/lerobot_datasets.txt
