# %% [markdown]
# ### Markdown 化

# %%
import sys
from pathlib import Path
from nbconvert import MarkdownExporter
p = Path("/vla/workspace/my_tbot/.code/LetMeSeeSee/prompt_policy.ipynb")
p.with_suffix(".md").write_text(MarkdownExporter().from_filename(str(p))[0], encoding="utf-8")
# Out:
# /vla/.conda/miniconda3/envs/myvla/lib/python3.10/site-packages/nbformat/__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# 8559

# %% [markdown]
# ### 查询lerobort数据集

# %%
#!/usr/bin/env python3
import os
import sys
import json
from pathlib import Path

def is_lerobot_dataset(dir_path: Path) -> bool:
    """检查是否为 LeRobot 数据集"""
    data_dir = dir_path / "data"
    meta_dir = dir_path / "meta"
    info_file = meta_dir / "info.json"
    
    if data_dir.is_dir() and meta_dir.is_dir() and info_file.is_file():
        try:
            with open(info_file, 'r', encoding='utf-8') as f:
                json.load(f)          # 验证 JSON 格式
            return True
        except:
            return False
    return False

def find_lerobot_datasets(root_path: Path, output_file: str = "lerobot_datasets.txt"):
    """递归查找所有 LeRobot 数据集"""
    found = []
    print(f"正在搜索: {root_path}\n")
    
    for dirpath, _, _ in os.walk(root_path):
        current = Path(dirpath)
        if is_lerobot_dataset(current):
            full_path = str(current.absolute())
            found.append(full_path)
            print(f"✅ 找到 LeRobot 数据集: {full_path}")
    
    if found:
        with open(output_file, 'w', encoding='utf-8') as f:
            for p in sorted(found):
                f.write(p + '\n')
        print(f"\n🎉 共找到 {len(found)} 个 LeRobot 数据集！")
        print(f"路径已保存至: {output_file}")
    else:
        print("\n未找到任何 LeRobot 数据集。")

if __name__ == "__main__":

    root = "/share/RoboTwin-LeRobot-v3.0"
    find_lerobot_datasets(root,output_file=f"{root}/lerobot_datasets.txt")
# Out:
# 正在搜索: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot
#
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/arrange_fruits_in_basket
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/arrange_flowers
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/move_objects_into_box
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/plug_in_network_cable
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/make_vegetarian_sandwich
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/wipe_the_table
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/arrange_paper_cups
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/turn_on_light_switch
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/hang_toothbrush_cup
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/put_cup_on_coaster
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/place_shoes_on_rack
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/sort_books
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/open_the_drawer
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/fold_dishcloth
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/sort_electronic_products
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/pour_fries_into_plate
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/search_green_boxes
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/shred_scrap_paper
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/clean_dining_table
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/water_potted_plant
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/stack_color_blocks
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/set_the_plates
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/turn_on_faucet
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/stack_bowls
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/press_three_buttons
# ✅ 找到 LeRobot 数据集: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/put_opener_in_drawer
#
# 🎉 共找到 26 个 LeRobot 数据集！
# 路径已保存至: /public-data/RoboChallenge/Traly__RoboChallenge-lerobot/lerobot_datasets.txt
